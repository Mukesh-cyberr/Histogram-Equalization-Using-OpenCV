# %% [markdown]
# # Histogram-Equalization-Using-OpenCV

# %% [markdown]
# ## Name:Mukesh Raj D
# ## Reg No:212224100038

# %%
# !pip install opencv-python
import cv2
from matplotlib import pyplot as plt
# Out:
# Requirement already satisfied: opencv-python in c:\users\mukes\anaconda3\lib\site-packages (4.13.0.92)
# Requirement already satisfied: numpy>=2 in c:\users\mukes\anaconda3\lib\site-packages (from opencv-python) (2.3.5)

# %%
# Load the color image
image = cv2.imread("C:\\Users\\mukes\\Downloads\\parrot.jpg")

# %%
# Convert the image to grayscale
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(gray_image, cmap='gray')
plt.title('Original Grayscale Image')
plt.axis('off')

print("Name : MUKESH RAJ D")
print("REG NO: 212224100038")
# Out:
# Name : MUKESH RAJ D
# REG NO: 212224100038

# %%
hist_original = cv2.calcHist([gray_image], [0], None, [256], [0, 256])

# %%
plt.plot(hist_original, color='black')
plt.title('Original Histogram')
plt.xlim([0, 256])

print("Name : MUKESH RAJ D")
print("REG NO: 212224100038")
# Out:
# Name : MUKESH RAJ D
# REG NO: 212224100038

# %%
# Apply histogram equalization
equalized_image = cv2.equalizeHist(gray_image)

# %%
plt.imshow(equalized_image, cmap='gray')
plt.title('Equalized Image')
plt.axis('off')

print("Name : MUKESH RAJ D")
print("REG NO: 212224100038")
# Out:
# Name : MUKESH RAJ D
# REG NO: 212224100038

# %%
hist_equalized = cv2.calcHist([equalized_image], [0], None, [256], [0, 256])

# %%
plt.plot(hist_equalized, color='black')
plt.title('Equalized Histogram')
plt.xlim([0, 256])

print("Name : MUKESH RAJ D")
print("REG NO: 212224100038")
# Out:
# Name : MUKESH RAJ D
# REG NO: 212224100038
